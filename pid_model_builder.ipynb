# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

# %%
# %run pid_model_builder_main.py
# Out:
# 2025-06-01 01:04:58,520 - INFO - [config_loader] - Utilisation du nom de base personnalisé './trace/pid_model_builder_log' pour le fichier de log (depuis la configuration).
# 2025-06-01 01:04:58,523 - INFO - [config_loader] - Journalisation configurée. Logs également sauvegardés dans : C:\Jupyter\pid_project\trace\pid_model_builder_log.txt
# 2025-06-01 01:04:58,524 - INFO - [config_loader] - Configuration chargée depuis 'C:\Jupyter\pid_project\pid_model_builder.ini'.
# INFO - [pid_model_builder_main] - --- Démarrage du script (fichier exécuté: pid_model_builder_main.py) ---
# INFO - [pid_model_builder_main] - --- Utilisation du nom de base 'pid_model_builder' pour le fichier de configuration .ini ---
# INFO - [pid_model_builder_main] - --- Démarrage de la phase de création de modèle de procédé ---
# INFO - [db_utils] - Connexion à SQL Server 'FRCDKSPA-0002/Runtime' avec l'utilisateur 'USE_Runtime'.
# INFO - [db_utils] - Connexion à la base de données réussie et testée.
# ...
