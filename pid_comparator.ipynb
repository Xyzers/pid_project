# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

# %%
# %run pid_comparator_main.py
# Out:
# 2025-06-02 17:29:50,349 - INFO - [config_loader] - Utilisation du nom de base personnalisé './trace/pid_comparator_log' pour le fichier de log (depuis la configuration).
# 2025-06-02 17:29:50,352 - INFO - [config_loader] - Journalisation configurée. Logs également sauvegardés dans : C:\Jupyter\pid_project\trace\pid_comparator_log.txt
# 2025-06-02 17:29:50,353 - INFO - [config_loader] - Configuration chargée depuis 'C:\Jupyter\pid_project\pid_comparator.ini'.
# 2025-06-02 17:29:50,354 - INFO - [pid_comparator_main] - --- Démarrage pid_comparator.py ---
# INFO - [db_utils] - Connexion à SQL Server 'FRCDKSPA-0002/Runtime' avec l'utilisateur 'USE_Runtime'.
# INFO - [db_utils] - Connexion à la base de données réussie et testée.
# INFO - [db_utils] - Construction de la requête SQL...
# INFO - [db_utils] - Requête SQL construite:
#
#     SELECT DateTime, MAX(CASE WHEN TagName = 'N1N2_lt_4401' THEN Value END) AS PV_real,
# ...
